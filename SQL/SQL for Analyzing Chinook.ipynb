# %% [markdown]
# # # SQL for Analyzing Chinook

# %% [markdown]
# author: Sirikwan Unp.

# %% [markdown]
# Date: 11/3/66

# %%
# !conda install -yc conda-forge ipython-sql
# Out:
# Collecting package metadata (current_repodata.json): ...working... done
# Solving environment: ...working... done
#
# # All requested packages already installed.

# %%
# %%capture
# %load_ext sql
# %sql sqlite:///chinook.db

# %% [markdown]
# 1. show the Customers from Brazil

# %%
# %%sql
# SELECT *
# FROM Customers
# WHERE Country == 'Brazil';
# Out:
#  * sqlite:///chinook.db
# Done.
# [(1, 'Luís', 'Gonçalves', 'Embraer - Empresa Brasileira de Aeronáutica S.A.', 'Av. Brigadeiro Faria Lima, 2170', 'São José dos Campos', 'SP', 'Brazil', '12227-000', '+55 (12) 3923-5555', '+55 (12) 3923-5566', 'luisg@embraer.com.br', 3),
#  (10, 'Eduardo', 'Martins', 'Woodstock Discos', 'Rua Dr. Falcão Filho, 155', 'São Paulo', 'SP', 'Brazil', '01007-010', '+55 (11) 3033-5446', '+55 (11) 3033-4564', 'eduardo@woodstock.com.br', 4),
#  (11, 'Alexandre', 'Rocha', 'Banco do Brasil S.A.', 'Av. Paulista, 2022', 'São Paulo', 'SP', 'Brazil', '01310-200', '+55 (11) 3055-3278', '+55 (11) 3055-8131', 'alero@uol.com.br', 5),
#  (12, 'Roberto', 'Almeida', 'Riotur', 'Praça Pio X, 119', 'Rio de Janeiro', 'RJ', 'Brazil', '20040-020', '+55 (21) 2271-7000', '+55 (21) 2271-7070', 'roberto.almeida@riotur.gov.br', 3),
#  (13, 'Fernanda', 'Ramos', None, 'Qe 7 Bloco G', 'Brasília', 'DF', 'Brazil', '71020-677', '+55 (61) 3363-5547', '+55 (61) 3363-7855', 'fernadaramos4@uol.com.br', 4)]

# %% [markdown]
# 2. show a unique list of billing countries from the Invoice table

# %%
# %%sql
# select 	DISTINCT BillingCountry
# FROM invoices;
# Out:
#  * sqlite:///chinook.db
# Done.
# [('Germany',),
#  ('Norway',),
#  ('Belgium',),
#  ('Canada',),
#  ('USA',),
#  ('France',),
#  ('Ireland',),
#  ('United Kingdom',),
#  ('Australia',),
#  ('Chile',),
#  ('India',),
#  ('Brazil',),
#  ('Portugal',),
#  ('Netherlands',),
#  ('Spain',),
#  ('Sweden',),
#  ('Czech Republic',),
#  ('Finland',),
#  ('Denmark',),
#  ('Italy',),
#  ('Poland',),
#  ('Austria',),
#  ('Hungary',),
#  ('Argentina',)]

# %% [markdown]
# 3. How many Invoices were there in each year

# %%
# %%sql
# select  year,
#         Count(year)
# FROM (
#     SELECT strftime('%Y',invoiceDate) as year
#     FROM invoices
# )as sub
# GROUP by year;
# Out:
#  * sqlite:///chinook.db
# Done.
# [('2009', 83), ('2010', 83), ('2011', 83), ('2012', 83), ('2013', 80)]

# %% [markdown]
# 4. How many tracks in each genre?

# %%
# %%sql
# select  genres.name,
#         count()
# from tracks, genres
# WHERE genres.GenreId = tracks.GenreId
# GROUP by genres.Name;
# Out:
#  * sqlite:///chinook.db
# Done.
# [('Alternative', 40),
#  ('Alternative & Punk', 332),
#  ('Blues', 81),
#  ('Bossa Nova', 15),
#  ('Classical', 74),
#  ('Comedy', 17),
#  ('Drama', 64),
#  ('Easy Listening', 24),
#  ('Electronica/Dance', 30),
#  ('Heavy Metal', 28),
#  ('Hip Hop/Rap', 35),
#  ('Jazz', 130),
#  ('Latin', 579),
#  ('Metal', 374),
#  ('Opera', 1),
#  ('Pop', 48),
#  ('R&B/Soul', 61),
#  ('Reggae', 58),
#  ('Rock', 1297),
#  ('Rock And Roll', 12),
#  ('Sci Fi & Fantasy', 26),
#  ('Science Fiction', 13),
#  ('Soundtrack', 43),
#  ('TV Shows', 93),
#  ('World', 28)]

# %% [markdown]
# 5. How many tracks does the Artist ‘Lost’ have?

# %%
# %%sql
# SELECT count(tracks.TrackId)
# FROM tracks
# JOIN albums on albums.AlbumId = tracks.AlbumId
# JOIN artists on albums.ArtistId = artists.ArtistId
# WHERE artists.name = 'Lost';
# Out:
#  * sqlite:///chinook.db
# Done.
# [(92,)]

# %% [markdown]
# 6. top 10 countries that buy the most?

# %%
# %%sql
# SELECT  BillingCountry as Country,
#         Count(InvoiceId) as Number_of_purchase
# FROM  invoices
# GROUP by Country
# ORDER by 2 DESC
# LIMIT 10;
# Out:
#  * sqlite:///chinook.db
# Done.
# [('USA', 91),
#  ('Canada', 56),
#  ('France', 35),
#  ('Brazil', 35),
#  ('Germany', 28),
#  ('United Kingdom', 21),
#  ('Portugal', 14),
#  ('Czech Republic', 14),
#  ('India', 13),
#  ('Sweden', 7)]

# %% [markdown]
# 7. Top 10 countries that buy the most music?

# %%
# %%sql
# SELECT  customers.Country,
#         count(invoice_items.Quantity) As Number_of_purchase_tracks
# FROM invoice_items
# Join invoices on invoice_items.InvoiceId = invoices.InvoiceId
# Join customers on customers.CustomerId = invoices.CustomerId
# GROUP by Country
# ORDER by 2 DESC
# LIMIT 10;
# Out:
#  * sqlite:///chinook.db
# Done.
# [('USA', 494),
#  ('Canada', 304),
#  ('France', 190),
#  ('Brazil', 190),
#  ('Germany', 152),
#  ('United Kingdom', 114),
#  ('Portugal', 76),
#  ('Czech Republic', 76),
#  ('India', 74),
#  ('Sweden', 38)]

# %% [markdown]
# 8. whose made the most sales?

# %%
# %%sql
# select  employees.EmployeeId,
#         employees.FirstName || " " ||employees.LastName as employee_name,
#         count(invoices.InvoiceId) as 'Total of sales'
# FROM invoices
# Join customers on customers.CustomerId = invoices.CustomerId
# Join employees on employees.EmployeeId = customers.SupportRepId
# GROUP by employees.EmployeeId
# ORDER by 3 DESC;
# Out:
#  * sqlite:///chinook.db
# Done.
# [(3, 'Jane Peacock', 146),
#  (4, 'Margaret Park', 140),
#  (5, 'Steve Johnson', 126)]

# %% [markdown]
# 9. How many sales of each album?

# %%
# %%sql
# SELECT  artists.Name as artist_name,
#         albums.Title as album_name,
#         count(albums.Title) as number_of_sale
# from invoice_items
# JOIN tracks on tracks.TrackId = invoice_items.TrackId
# JOIN albums on albums.AlbumId = tracks.AlbumId
# JOIN artists on artists.ArtistId = albums.ArtistId
# GROUP by 2
# ORDER by 3 desc;
# Out:
#  * sqlite:///chinook.db
# Done.
# [('Chico Buarque', 'Minha Historia', 27),
#  ('Lenny Kravitz', 'Greatest Hits', 26),
#  ('Eric Clapton', 'Unplugged', 25),
#  ('Titãs', 'Acústico', 22),
#  ('Kiss', 'Greatest Kiss', 20),
#  ('Caetano Veloso', 'Prenda Minha', 19),
#  ('The Who', 'My Generation - The Very Best Of The Who', 19),
#  ('Creedence Clearwater Revival', 'Chronicle, Vol. 2', 19),
#  ('Green Day', 'International Superhits', 18),
#  ('Creedence Clearwater Revival', 'Chronicle, Vol. 1', 18),
#  ('Battlestar Galactica (Classic)', 'Battlestar Galactica (Classic), Season 1', 18),
#  ('Os Paralamas Do Sucesso', 'Acústico MTV', 18),
#  ("Guns N' Roses", 'Use Your Illusion I', 17),
#  ('Gene Krupa', "Up An' Atom", 17),
#  ('R.E.M.', 'The Best Of R.E.M.: The IRS Years', 17),
#  ('U2', 'Rattle And Hum', 17),
#  ('The Office', 'The Office, Season 3', 16),
#  ('U2', 'Instant Karma: The Amnesty International Campaign to Save Darfur', 16),
#  ('Chico Science & Nação Zumbi', 'Afrociberdelia', 16),
#  ('Toquinho & Vinícius', 'Vinícius De Moraes - Sem Limite', 15),
#  ('Eric Clapton', 'The Cream Of Clapton', 15),
#  ('Antônio Carlos Jobim', 'Chill: Brazil (Disc 2)', 15),
#  ('Os Paralamas Do Sucesso', 'Arquivo Os Paralamas Do Sucesso', 15),
#  ('Green Day', 'American Idiot', 15),
#  ('Soundgarden', 'A-Sides', 15),
#  ('R.E.M.', 'New Adventures In Hi-Fi', 14),
#  ('Queen', 'Greatest Hits II', 14),
#  ('Smashing Pumpkins', 'Rotten Apples: Greatest Hits', 13),
#  ('Gilberto Gil', 'Quanta Gente Veio Ver (Live)', 13),
#  ('Lost', 'Lost, Season 2', 13),
#  ('Heroes', 'Heroes, Season 1', 13),
#  ('Elis Regina', 'Elis Regina-Minha História', 13),
#  ('O Terço', 'Compositores', 13),
#  ('Faith No More', 'Angel Dust', 13),
#  ('Faith No More', 'Album Of The Year', 13),
#  ('Titãs', 'Volume Dois', 12),
#  ('James Brown', 'Sex Machine', 12),
#  ('Tim Maia', 'Serie Sem Limite (Disc 2)', 12),
#  ('Tim Maia', 'Serie Sem Limite (Disc 1)', 12),
#  ('Metallica', 'ReLoad', 12),
#  ('Queen', 'News Of The World', 12),
#  ('System Of A Down', 'Mezmerize', 12),
#  ('Metallica', 'Garage Inc. (Disc 2)', 12),
#  ('Cássia Eller', 'Cássia Eller - Coleção Sem Limite [Disc 2]', 12),
#  ('Bruce Dickinson', 'Chemical Wedding', 12),
#  ('Battlestar Galactica', 'Battlestar Galactica, Season 3', 12),
#  ('Amy Winehouse', 'Back to Black', 12),
#  ('Os Paralamas Do Sucesso', 'Arquivo II', 12),
#  ('U2', 'War', 11),
#  ('Various Artists', 'Vozes do MPB', 11),
#  ('Kiss', 'Unplugged [Live]', 11),
#  ('Iron Maiden', 'The X Factor', 11),
#  ('U2', 'The Best Of 1980-1990', 11),
#  ('Lost', 'Lost, Season 3', 11),
#  ('Metallica', 'Load', 11),
#  ('Metallica', "Kill 'Em All", 11),
#  ('Smashing Pumpkins', 'Judas 0: B-Sides and Rarities', 11),
#  ('Spyro Gyra', 'Heart of the Night', 11),
#  ('Queen', 'Greatest Hits I', 11),
#  ('Body Count', 'Body Count', 11),
#  ('U2', 'B-Sides 1980-1990', 11),
#  ("Guns N' Roses", 'Use Your Illusion II', 10),
#  ('Ozzy Osbourne', 'Tribute', 10),
#  ('The Clash', 'The Singles', 10),
#  ('Van Halen', 'The Best Of Van Halen, Vol. I', 10),
#  ('The Tea Party', 'Tangents', 10),
#  ('Marvin Gaye', 'Seek And Shall Find: More Of The Best (1963-1981)', 10),
#  ('Raul Seixas', 'Raul Seixas', 10),
#  ('U2', 'Pop', 10),
#  ('Olodum', 'Olodum', 10),
#  ('Frank Sinatra', 'My Way: The Best Of Frank Sinatra [Disc 1]', 10),
#  ('Metallica', 'Master Of Puppets', 10),
#  ('Lost', 'Lost, Season 1', 10),
#  ('Judas Priest', 'Living After Midnight', 10),
#  ('U2', 'How To Dismantle An Atomic Bomb', 10),
#  ('AC/DC', 'For Those About To Rock We Salute You', 10),
#  ('Stone Temple Pilots', 'Core', 10),
#  ('Red Hot Chili Peppers', 'Blood Sugar Sex Magik', 10),
#  ('Aerosmith', 'Big Ones', 10),
#  ('Led Zeppelin', 'BBC Sessions [Disc 2] [Live]', 10),
#  ('U2', 'Zooropa', 9),
#  ('Iron Maiden', 'The Number of The Beast', 9),
#  ('Iron Maiden', 'Seventh Son of a Seventh Son', 9),
#  ('The Cult', 'Pure Cult: The Best Of The Cult (For Rockers, Ravers, Lovers & Sinners) [UK]', 9),
#  ('Iron Maiden', 'Powerslave', 9),
#  ('R.E.M. Feat. Kate Pearson', 'Out Of Time', 9),
#  ('Planet Hemp', 'Os Cães Ladram Mas A Caravana Não Pára', 9),
#  ('Passengers', 'Original Soundtracks 1', 9),
#  ('Spyro Gyra', 'Morning Dance', 9),
#  ('Gonzaguinha', 'Meus Momentos', 9),
#  ('Pearl Jam', 'Live On Two Legs [Live]', 9),
#  ('Led Zeppelin', 'Led Zeppelin III', 9),
#  ('Led Zeppelin', 'Led Zeppelin II', 9),
#  ('Led Zeppelin', 'Led Zeppelin I', 9),
#  ('Faith No More', 'King For A Day Fool For A Lifetime', 9),
#  ('Stevie Ray Vaughan & Double Trouble', 'In Step', 9),
#  ('Djavan', 'Djavan Ao Vivo - Vol. 1', 9),
#  ('Djavan', 'Djavan Ao Vivo - Vol. 02', 9),
#  ('Chico Science & Nação Zumbi', 'Da Lama Ao Caos', 9),
#  ('Cássia Eller', 'Cássia Eller - Sem Limite [Disc 1]', 9),
#  ('Red Hot Chili Peppers', 'Californication', 9),
#  ('Incognito', 'Blue Moods', 9),
#  ('Metallica', 'Black Album', 9),
#  ("Guns N' Roses", 'Appetite for Destruction', 9),
#  ('Zeca Pagodinho', 'Ao Vivo [IMPORT]', 9),
#  ('Cidade Negra', 'Acústico MTV [Live]', 9),
#  ('Legião Urbana', 'A TempestadeTempestade Ou O Livro Dos Dias', 9),
#  ('Page & Plant', 'Walking Into Clarksdale', 8),
#  ('UB40', 'UB40 The Best Of - Volume Two [UK]', 8),
#  ('Men At Work', 'The Best Of Men At Work', 8),
#  ('Funk Como Le Gusta', 'Roda De Funk', 8),
#  ('Iron Maiden', 'Rock In Rio [CD2]', 8),
#  ('Iron Maiden', 'Rock In Rio [CD1]', 8),
#  ('Iron Maiden', 'No Prayer For The Dying', 8),
#  ('Os Mutantes', 'Minha História', 8),
#  ('Milton Nascimento', 'Milton Nascimento Ao Vivo', 8),
#  ('Legião Urbana', 'Mais Do Mesmo', 8),
#  ('Lulu Santos', 'Lulu Santos - RCA 100 Anos De Música - Álbum 01', 8),
#  ('Iron Maiden', 'Live After Death', 8),
#  ('Alanis Morissette', 'Jagged Little Pill', 8),
#  ('David Coverdale', 'Into The Light', 8),
#  ('Led Zeppelin', 'In Through The Out Door', 8),
#  ('House Of Pain', 'House of Pain', 8),
#  ('R.E.M.', 'Green', 8),
#  ('Godsmack', 'Faceless', 8),
#  ('Falamansa', 'Deixa Entrar', 8),
#  ('Red Hot Chili Peppers', 'By The Way', 8),
#  ('Marisa Monte', 'Barulhinho Bom', 8),
#  ('Jimi Hendrix', 'Are You Experienced?', 8),
#  ('Antônio Carlos Jobim', 'Warner 25 Anos', 7),
#  ('The Rolling Stones', 'Voodoo Lounge', 7),
#  ('Iron Maiden', 'Virtual XI', 7),
#  ('Def Leppard', "Vault: Def Leppard's Greatest Hits", 7),
#  ('The Tea Party', 'Transmission', 7),
#  ('Faith No More', 'The Real Thing', 7),
#  ('The Police', 'The Police Greatest Hits', 7),
#  ('Buddy Guy', 'The Best Of Buddy Guy - The Millenium Collection', 7),
#  ('Jamiroquai', 'Synkronized', 7),
#  ('Metallica', 'St. Anger', 7),
#  ('Ozzy Osbourne', 'Speak of the Devil', 7),
#  ('Pearl Jam', 'Riot Act', 7),
#  ('O Rappa', 'Radio Brasil (O Som da Jovem Vanguarda) - Seleccao de Henrique Amaro', 7),
#  ('Mötley Crüe', 'Motley Crue Greatest Hits', 7),
#  ('Milton Nascimento', 'Minas', 7),
#  ('Miles Davis', 'Miles Ahead', 7),
#  ('The Black Crowes', 'Live [Disc 2]', 7),
#  ('The Black Crowes', 'Live [Disc 1]', 7),
#  ('Lost', 'LOST, Season 4', 7),
#  ('Led Zeppelin', 'Houses Of The Holy', 7),
#  ('JET', 'Get Born', 7),
#  ('Metallica', 'Garage Inc. (Disc 1)', 7),
#  ('Nirvana', 'From The Muddy Banks Of The Wishkah [Live]', 7),
#  ('Alice In Chains', 'Facelift', 7),
#  ('Van Halen', 'Diver Down', 7),
#  ('Cidade Negra', 'Cidade Negra - Hits', 7),
#  ('Marcos Valle', 'Chill: Brazil (Disc 1)', 7),
#  ('Raimundos', 'Cesta Básica', 7),
#  ('Black Sabbath', 'Black Sabbath Vol. 4 (Remaster)', 7),
#  ('The Cult', 'Beyond Good And Evil', 7),
#  ('Iron Maiden', 'A Real Dead One', 7),
#  ('Pearl Jam', 'Vs.', 6),
#  ('Vinícius De Moraes', 'Vinicius De Moraes', 6),
#  ('Van Halen', 'Van Halen III', 6),
#  ('Van Halen', 'Van Halen', 6),
#  ('The Office', 'The Office, Season 2', 6),
#  ('Miles Davis', 'The Essential Miles Davis [Disc 1]', 6),
#  ('Foo Fighters', 'The Colour And The Shape', 6),
#  ('Ed Motta', 'The Best of Ed Motta', 6),
#  ('Santana', 'Supernatural', 6),
#  ('Various Artists', 'Sambas De Enredo 2001', 6),
#  ('Metallica', 'Ride The Lightning', 6),
#  ('Rush', 'Retrospective I (1974-1980)', 6),
#  ('Pearl Jam', 'Pearl Jam', 6),
#  ('The Rolling Stones', 'No Security', 6),
#  ('Skank', 'Maquinarama', 6),
#  ('Iron Maiden', 'Live At Donington 1992 (Disc 2)', 6),
#  ('AC/DC', 'Let There Be Rock', 6),
#  ('Jota Quest', 'Jota Quest-1995', 6),
#  ('Jorge Ben', 'Jorge Ben Jor 25 Anos', 6),
#  ('Foo Fighters', 'In Your Honor [Disc 2]', 6),
#  ('Led Zeppelin', 'IV', 6),
#  ('Amy Winehouse', 'Frank', 6),
#  ('Jamiroquai', 'Emergency On Planet Earth', 6),
#  ('Mônica Marianno', 'Demorou...', 6),
#  ('Velvet Revolver', 'Contraband', 6),
#  ('Led Zeppelin', 'Coda', 6),
#  ('Various Artists', 'Carnaval 2001', 6),
#  ('João Suplicy', 'Cafezinho', 6),
#  ('Iron Maiden', 'Brave New World', 6),
#  ('BackBeat', 'BackBeat Soundtrack', 6),
#  ('Led Zeppelin', 'BBC Sessions [Disc 1] [Live]', 6),
#  ('Various Artists', 'Axé Bahia 2001', 6),
#  ('Audioslave', 'Audioslave', 6),
#  ('U2', "All That You Can't Leave Behind", 6),
#  ('U2', 'Achtung Baby', 6),
#  ('Motörhead', 'Ace Of Spades', 6),
#  ('Iron Maiden', 'A Matter of Life and Death', 6),
#  ('Metallica', '...And Justice For All', 6),
#  ('Terry Bozzio, Tony Levin & Steve Stevens', '[1997] Black Light Syndrome', 5),
#  ('Jamiroquai', 'The Return Of The Space Cowboy', 5),
#  ("Paul D'Ianno", 'The Beast Live', 5),
#  ('Deep Purple', 'The Battle Rages On', 5),
#  ('Iron Maiden', 'Somewhere in Time', 5),
#  ('Audioslave', 'Revelations', 5),
#  ('Deep Purple', 'Purpendicular', 5),
#  ('Led Zeppelin', 'Presence', 5),
#  ('Iron Maiden', 'Piece Of Mind', 5),
#  ('Led Zeppelin', 'Physical Graffiti [Disc 2]', 5),
#  ('Audioslave', 'Out Of Exile', 5),
#  ('Foo Fighters', 'One By One', 5),
#  ('Nirvana', 'Nevermind', 5),
#  ('Cláudio Zoli', 'Na Pista', 5),
#  ('Marillion', 'Misplaced Childhood', 5),
#  ('Lulu Santos', 'Lulu Santos - RCA 100 Anos De Música - Álbum 02', 5),
#  ('Deep Purple', "Knocking at Your Back Door: The Best Of Deep Purple in the 80's", 5),
#  ('Iron Maiden', 'Killers', 5),
#  ('Foo Fighters', 'In Your Honor [Disc 1]', 5),
#  ('The Rolling Stones', 'Hot Rocks, 1964-1971 (Disc 1)', 5),
#  ('Iron Maiden', 'Fear Of The Dark', 5),
#  ('Iron Maiden', 'Dance Of Death', 5),
#  ('Deep Purple', 'Come Taste The Band', 5),
#  ('Gilberto Gil', 'As Canções de Eu Tu Eles', 5),
#  ('Black Label Society', 'Alcohol Fueled Brewtality Live! [Disc 1]', 5),
#  ('Iron Maiden', 'A Real Live One', 5),
#  ('Scorpions', '20th Century Masters - The Millennium Collection: The Best of Scorpions', 5),
#  ('Miles Davis', 'The Essential Miles Davis [Disc 2]', 4),
#  ('The Doors', 'The Doors', 4),
#  ('Billy Cobham', 'The Best Of Billy Cobham', 4),
#  ('Pearl Jam', 'Ten', 4),
#  ('Temple of the Dog', 'Temple of the Dog', 4),
#  ('Joe Satriani', 'Surfing with the Alien (Remastered)', 4),
#  ('Deep Purple', 'Stormbringer', 4),
#  ('Deep Purple', 'Slaves And Masters', 4),
#  ('Apocalyptica', 'Plays Metallica By Four Cellos', 4),
#  ('Dennis Chambers', 'Outbreak', 4),
#  ('Skank', 'O Samba Poconé', 4),
#  ('Deep Purple', 'Machine Head', 4),
#  ('Deep Purple', 'MK III The Final Concerts [Disc 1]', 4),
#  ('Iron Maiden', 'Live At Donington 1992 (Disc 1)', 4),
#  ('Iron Maiden', 'Iron Maiden', 4),
#  ('Deep Purple', 'Fireball', 4),
#  ('Pink Floyd', 'Dark Side Of The Moon', 4),
#  ('Chris Cornell', 'Carry On', 4),
#  ('Frank Zappa & Captain Beefheart', 'Bongo Fury', 4),
#  ('Led Zeppelin', 'The Song Remains The Same (Disc 1)', 3),
#  ('The Office', 'The Office, Season 1', 3),
#  ('Santana', 'Santana Live', 3),
#  ('Santana', 'Santana - As Years Go By', 3),
#  ('Accept', 'Restless and Wild', 3),
#  ('Ozzy Osbourne', 'No More Tears (Remastered)', 3),
#  ('Deep Purple', 'Deep Purple In Rock', 3),
#  ('Black Label Society', 'Alcohol Fueled Brewtality Live! [Disc 2]', 3),
#  ('Led Zeppelin', 'The Song Remains The Same (Disc 2)', 2),
#  ('Caetano Veloso', 'Sozinho Remix Ao Vivo', 2),
#  ('Emerson String Quartet', "Schubert: The Late String Quartets & String Quintet (3 CD's)", 2),
#  ('Chicago Symphony Orchestra & Fritz Reiner', 'Scheherazade', 2),
#  ('Gilberto Gil', 'Quanta Gente Veio ver--Bônus De Carnaval', 2),
#  ('Equale Brass Ensemble, John Eliot Gardiner & Munich Monteverdi Orchestra and Choir', 'Purcell: Music for the Queen Mary', 2),
#  ('Led Zeppelin', 'Physical Graffiti [Disc 1]', 2),
#  ('Ozzy Osbourne', 'Diary of a Madman (Remastered)', 2),
#  ('Black Sabbath', 'Black Sabbath', 2),
#  ('Michael Tilson Thomas & San Francisco Symphony', 'Berlioz: Symphonie Fantastique', 2),
#  ('Accept', 'Balls to the Wall', 2),
#  ('Academy of St. Martin in the Fields, Sir Neville Marriner & Thurston Dart', 'Bach: Orchestral Suites Nos. 1 - 4', 2),
#  ('Aquaman', 'Aquaman', 2),
#  ("Kent Nagano and Orchestre de l'Opéra de Lyon", 'Weill: The Seven Deadly Sins', 1),
#  ('Sir Georg Solti & Wiener Philharmoniker', 'Wagner: Favourite Overtures', 1),
#  ('Dread Zeppelin', 'Un-Led-Ed', 1),
#  ('Academy of St. Martin in the Fields & Sir Neville Marriner', 'The World of Classical Favourites', 1),
#  ('Deep Purple', 'The Final Concerts (Disc 2)', 1),
#  ('Antal Doráti & London Symphony Orchestra', "Tchaikovsky: 1812 Festival Overture, Op.49, Capriccio Italien & Beethoven: Wellington's Victory", 1),
#  ('Martin Roscoe', 'Szymanowski: Piano Works, Vol. 1', 1),
#  ('The 12 Cellists of The Berlin Philharmonic', 'South American Getaway', 1),
#  ('Berliner Philharmoniker & Hans Rosbaud', 'Sibelius: Finlandia', 1),
#  ('Eugene Ormandy', 'Respighi:Pines of Rome', 1),
#  ('Roger Norrington, London Classical Players', 'Purcell: The Fairy Queen', 1),
#  ('Michael Tilson Thomas & San Francisco Symphony', 'Prokofiev: Romeo & Juliet', 1),
#  ('English Concert & Trevor Pinnock', 'Pachelbel: Canon & Gigue', 1),
#  ('Göteborgs Symfoniker & Neeme Järvi', 'Nielsen: The Six Symphonies', 1),
#  ('Habib Koité and Bamada', 'Muso Ko', 1),
#  ('Berliner Philharmoniker & Herbert Von Karajan', 'Mozart: Symphonies Nos. 40 & 41', 1),
#  ('Philharmonia Orchestra & Sir Neville Marriner', "Mendelssohn: A Midsummer Night's Dream", 1),
#  ('Michele Campanella', "Liszt - 12 Études D'Execution Transcendante", 1),
#  ('Julian Bream', 'J.S. Bach: Chaconne, Suite in E Minor, Partita in E Major & Prelude, Fugue and Allegro', 1),
#  ('Eugene Ormandy', 'Holst: The Planets, Op. 32 & Vaughan Williams: Fantasies', 1),
#  ('Royal Philharmonic Orchestra & Sir Thomas Beecham', 'Haydn: Symphonies 99 - 104', 1),
#  ('Scholars Baroque Ensemble', 'Handel: The Messiah (Highlights)', 1),
#  ('Adrian Leaper & Doreen de Feis', 'Górecki: Symphony No. 3', 1),
#  ('Berliner Philharmoniker & Herbert Von Karajan', 'Grieg: Peer Gynt Suites & Sibelius: Pelléas et Mélisande', 1),
#  ('Academy of St. Martin in the Fields, John Birch, Sir Neville Marriner & Sylvia McNair', 'Fauré: Requiem, Ravel: Pavane & Others', 1),
#  ('The Posies', 'Every Kind of Light', 1),
#  ("The King's Singers", 'English Renaissance', 1),
#  ('Felix Schmidt, London Symphony Orchestra & Rafael Frühbeck de Burgos', 'Elgar: Cello Concerto & Vaughan Williams: Fantasias', 1),
#  ('Luciana Souza/Romero Lubambo', 'Duos II', 1),
#  ('Emanuel Ax, Eugene Ormandy & Philadelphia Orchestra', 'Chopin: Piano Concertos Nos. 1 & 2', 1),
#  ('Calexico', 'Carried to Dust (Bonus Track Version)', 1),
#  ('Ozzy Osbourne', 'Blizzard of Ozz', 1),
#  ('Otto Klemperer & Philharmonia Orchestra', "Beethoven: Symphony No. 6 'Pastoral' Etc.", 1),
#  ('Maurizio Pollini', 'Beethoven Piano Sonatas: Moonlight & Pastorale', 1),
#  ('Yehudi Menuhin', 'Bartok: Violin & Viola Concertos', 1),
#  ('Ozzy Osbourne', 'Bark at the Moon (Remastered)', 1),
#  ('Yo-Yo Ma', 'Bach: The Cello Suites', 1),
#  ('Orchestra of The Age of Enlightenment', 'Bach: The Brandenburg Concertos', 1),
#  ('Edo de Waart & San Francisco Symphony', 'Adams, John: The Chairman Dances', 1)]

# %% [markdown]
# 10. Top 10 album selling artists

# %%
# %%sql
# SELECT  artists.Name as artist_name,
#         count(albums.Title) as number_of_sale
# from invoice_items
# JOIN tracks on tracks.TrackId = invoice_items.TrackId
# JOIN albums on albums.AlbumId = tracks.AlbumId
# JOIN artists on artists.ArtistId = albums.ArtistId
# GROUP by 1
# ORDER by 2 desc
# LIMIT 10;
# Out:
#  * sqlite:///chinook.db
# Done.
# [('Iron Maiden', 140),
#  ('U2', 107),
#  ('Metallica', 91),
#  ('Led Zeppelin', 87),
#  ('Os Paralamas Do Sucesso', 45),
#  ('Deep Purple', 44),
#  ('Faith No More', 42),
#  ('Lost', 41),
#  ('Eric Clapton', 40),
#  ('R.E.M.', 39)]
